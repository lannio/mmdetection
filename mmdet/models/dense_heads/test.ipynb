# %%
        loss = torch.pow(torch.norm(x, dim=(2,3)), 2)
        return torch.mean(loss,1)

# %%
import torch

# %%
a=torch.rand(16,4,10,10)

# %%
a
# Out:
# tensor([[[[0.5069, 0.8580, 0.9679,  ..., 0.6572, 0.8356, 0.0021],
#           [0.4662, 0.8322, 0.1630,  ..., 0.8270, 0.0522, 0.7179],
#           [0.6786, 0.0394, 0.0614,  ..., 0.0647, 0.5487, 0.4567],
#           ...,
#           [0.9320, 0.8454, 0.8390,  ..., 0.0950, 0.9022, 0.8748],
#           [0.0691, 0.5484, 0.6642,  ..., 0.8939, 0.9622, 0.1953],
#           [0.9498, 0.1054, 0.0036,  ..., 0.4123, 0.9975, 0.6248]],
#
#          [[0.7624, 0.1771, 0.3323,  ..., 0.7977, 0.7713, 0.7604],
#           [0.9770, 0.2643, 0.5608,  ..., 0.2385, 0.7716, 0.3054],
#           [0.0215, 0.9513, 0.8492,  ..., 0.6763, 0.1049, 0.0196],
#           ...,
#           [0.2339, 0.8433, 0.6863,  ..., 0.0716, 0.4026, 0.9849],
#           [0.3446, 0.9089, 0.1997,  ..., 0.1872, 0.3419, 0.9184],
#           [0.8172, 0.4558, 0.9555,  ..., 0.6780, 0.7557, 0.5901]],
#
#          [[0.7563, 0.9756, 0.6819,  ..., 0.9278, 0.8772, 0.2242],
#           [0.6071, 0.7607, 0.0148,  ..., 0.1097, 0.3197, 0.6097],
#           [0.2327, 0.6141, 0.8254,  ..., 0.3471, 0.2414, 0.5278],
#           ...,
#           [0.6124, 0.6530, 0.9606,  ..., 0.3662, 0.7938, 0.8592],
#           [0.1722, 0.2501, 0.3133,  ..., 0.7204, 0.8854, 0.3289],
#           [0.1836, 0.0609, 0.1140,  ..., 0.8976, 0.9859, 0.7577]],
#
#          [[0.0275, 0.4052, 0.6072,  ..., 0.8651, 0.4384, 0.7550],
#           [0.9038, 0.4075, 0.1742,  ..., 0.1230, 0.9308, 0.5030],
#           [0.8291, 0.6273, 0.4645,  ..., 0.0365, 0.8442, 0.3408],
#           ...,
#           [0.5583, 0.5960, 0.6877,  ..., 0.2458, 0.1376, 0.8021],
#           [0.5939, 0.0767, 0.6651,  ..., 0.1176, 0.8017, 0.6158],
#           [0.5099, 0.5022, 0.7932,  ..., 0.7521, 0.1275, 0.1145]]],
#
#
#         [[[0.2930, 0.1405, 0.4005,  ..., 0.4374, 0.1178, 0.2208],
#           [0.6028, 0.5479, 0.2522,  ..., 0.5459, 0.5418, 0.4410],
#           [0.8336, 0.5530, 0.8804,  ..., 0.4930, 0.4663, 0.3530],
#           ...,
#           [0.6476, 0.5212, 0.6928,  ..., 0.2874, 0.9155, 0.5450],
#           [0.3274, 0.3854, 0.2688,  ..., 0.0393, 0.7408, 0.5489],
#           [0.1582, 0.6214, 0.3939,  ..., 0.0419, 0.6967, 0.1175]],
#
#          [[0.1107, 0.3713, 0.9990,  ..., 0.7014, 0.2498, 0.8074],
#           [0.9459, 0.8282, 0.1160,  ..., 0.5008, 0.9497, 0.5102],
#           [0.7476, 0.4703, 0.9554,  ..., 0.9143, 0.0726, 0.5952],
#           ...,
#           [0.7105, 0.0615, 0.3349,  ..., 0.4085, 0.7395, 0.1185],
#           [0.0325, 0.1874, 0.2125,  ..., 0.6785, 0.5515, 0.4297],
#           [0.5475, 0.3325, 0.1844,  ..., 0.4041, 0.7153, 0.7651]],
#
#          [[0.0633, 0.4494, 0.8449,  ..., 0.9444, 0.5981, 0.8209],
#           [0.5994, 0.7368, 0.9103,  ..., 0.2205, 0.0415, 0.6804],
#           [0.1369, 0.2965, 0.6412,  ..., 0.1332, 0.4993, 0.8896],
#           ...,
#           [0.0035, 0.1971, 0.7181,  ..., 0.9800, 0.9169, 0.8440],
#           [0.2111, 0.6515, 0.0309,  ..., 0.5059, 0.8928, 0.9713],
#           [0.9139, 0.1683, 0.0929,  ..., 0.0052, 0.7392, 0.2620]],
#
#          [[0.4256, 0.8862, 0.5805,  ..., 0.4325, 0.6852, 0.2556],
#           [0.4128, 0.3785, 0.3919,  ..., 0.1454, 0.9207, 0.3670],
#           [0.9968, 0.3320, 0.2597,  ..., 0.8407, 0.6945, 0.2849],
#           ...,
#           [0.3901, 0.6075, 0.5787,  ..., 0.6299, 0.2352, 0.6589],
#           [0.3962, 0.2874, 0.2802,  ..., 0.3809, 0.1864, 0.7626],
#           [0.6950, 0.4178, 0.3168,  ..., 0.2595, 0.0373, 0.2693]]],
#
#
#         [[[0.8169, 0.9319, 0.1882,  ..., 0.6260, 0.5170, 0.8966],
#           [0.3036, 0.8079, 0.9756,  ..., 0.8796, 0.9365, 0.3895],
#           [0.3025, 0.3921, 0.6960,  ..., 0.2317, 0.7099, 0.7879],
#           ...,
#           [0.6885, 0.5255, 0.1399,  ..., 0.4875, 0.7891, 0.3130],
#           [0.5222, 0.4700, 0.4558,  ..., 0.7344, 0.1454, 0.1517],
#           [0.5526, 0.6357, 0.3189,  ..., 0.8280, 0.4666, 0.3372]],
#
#          [[0.0404, 0.7330, 0.7140,  ..., 0.6197, 0.6513, 0.6722],
#           [0.9557, 0.5120, 0.4567,  ..., 0.1991, 0.8066, 0.2700],
#           [0.8091, 0.6970, 0.1235,  ..., 0.3191, 0.6452, 0.3724],
#           ...,
#           [0.7629, 0.9316, 0.0056,  ..., 0.3446, 0.7669, 0.3921],
#           [0.8394, 0.6108, 0.7508,  ..., 0.9268, 0.9211, 0.8560],
#           [0.3895, 0.5712, 0.5990,  ..., 0.6698, 0.2930, 0.1490]],
#
#          [[0.9328, 0.8264, 0.9371,  ..., 0.1543, 0.0173, 0.7888],
#           [0.0832, 0.9339, 0.7810,  ..., 0.3342, 0.5971, 0.8592],
#           [0.5379, 0.2798, 0.4016,  ..., 0.2511, 0.2711, 0.7989],
#           ...,
#           [0.8130, 0.3024, 0.7640,  ..., 0.5094, 0.8353, 0.9250],
#           [0.0257, 0.0234, 0.2921,  ..., 0.7222, 0.2243, 0.4325],
#           [0.3771, 0.8756, 0.0820,  ..., 0.3597, 0.6503, 0.6224]],
#
#          [[0.1159, 0.1019, 0.1366,  ..., 0.2175, 0.2538, 0.5860],
#           [0.3286, 0.8673, 0.1065,  ..., 0.5561, 0.1570, 0.0249],
#           [0.0362, 0.0388, 0.7750,  ..., 0.4510, 0.3938, 0.9805],
#           ...,
#           [0.7849, 0.6201, 0.2719,  ..., 0.7563, 0.7379, 0.3895],
#           [0.8540, 0.8000, 0.8582,  ..., 0.7768, 0.6893, 0.8168],
#           [0.6012, 0.8971, 0.4039,  ..., 0.0119, 0.9914, 0.2864]]],
#
#
#         ...,
#
#
#         [[[0.0493, 0.5364, 0.9375,  ..., 0.8204, 0.6062, 0.5496],
#           [0.6798, 0.7203, 0.4125,  ..., 0.9893, 0.1368, 0.4511],
#           [0.0059, 0.2655, 0.0067,  ..., 0.6114, 0.2686, 0.4049],
#           ...,
#           [0.6465, 0.9004, 0.6395,  ..., 0.2373, 0.2042, 0.5782],
#           [0.1728, 0.0777, 0.0263,  ..., 0.4678, 0.2208, 0.5574],
#           [0.6307, 0.4807, 0.5383,  ..., 0.1683, 0.2399, 0.2317]],
#
#          [[0.9235, 0.7991, 0.0905,  ..., 0.0022, 0.0453, 0.9147],
#           [0.0163, 0.3735, 0.5447,  ..., 0.1140, 0.8190, 0.4479],
#           [0.5007, 0.6550, 0.2359,  ..., 0.7916, 0.4372, 0.7365],
#           ...,
#           [0.8567, 0.0783, 0.6151,  ..., 0.6355, 0.5152, 0.1369],
#           [0.6369, 0.2042, 0.9115,  ..., 0.2055, 0.9707, 0.5244],
#           [0.1446, 0.2530, 0.5252,  ..., 0.4854, 0.1511, 0.9539]],
#
#          [[0.5577, 0.8712, 0.8130,  ..., 0.8786, 0.9779, 0.0015],
#           [0.3880, 0.1440, 0.9317,  ..., 0.1395, 0.3157, 0.2115],
#           [0.3489, 0.0723, 0.0628,  ..., 0.7571, 0.4827, 0.1301],
#           ...,
#           [0.9293, 0.4800, 0.1542,  ..., 0.1660, 0.2628, 0.2404],
#           [0.1059, 0.0414, 0.7901,  ..., 0.1313, 0.6183, 0.2535],
#           [0.8717, 0.7894, 0.5560,  ..., 0.2201, 0.7019, 0.8486]],
#
#          [[0.6744, 0.8966, 0.9820,  ..., 0.3592, 0.5936, 0.4724],
#           [0.4052, 0.6659, 0.8010,  ..., 0.7882, 0.4658, 0.9613],
#           [0.0727, 0.4083, 0.2533,  ..., 0.6164, 0.1666, 0.2324],
#           ...,
#           [0.2127, 0.4428, 0.0083,  ..., 0.0463, 0.0122, 0.7392],
#           [0.0455, 0.2463, 0.4034,  ..., 0.4329, 0.1128, 0.1009],
#           [0.4789, 0.2698, 0.6929,  ..., 0.7820, 0.4125, 0.1402]]],
#
#
#         [[[0.3763, 0.1816, 0.9775,  ..., 0.5064, 0.0265, 0.1737],
#           [0.0246, 0.4314, 0.4131,  ..., 0.2671, 0.5956, 0.8528],
#           [0.2427, 0.6915, 0.1871,  ..., 0.5545, 0.6216, 0.7059],
#           ...,
#           [0.9366, 0.3960, 0.2441,  ..., 0.7423, 0.0871, 0.0076],
#           [0.0108, 0.0808, 0.5737,  ..., 0.3058, 0.7551, 0.9582],
#           [0.9614, 0.4511, 0.3882,  ..., 0.2440, 0.1856, 0.0831]],
#
#          [[0.9953, 0.6292, 0.7724,  ..., 0.1305, 0.0216, 0.0222],
#           [0.9104, 0.9323, 0.7818,  ..., 0.6567, 0.3637, 0.4256],
#           [0.3117, 0.2478, 0.8192,  ..., 0.8416, 0.4469, 0.4502],
#           ...,
#           [0.3048, 0.0117, 0.2417,  ..., 0.9443, 0.8808, 0.3432],
#           [0.8395, 0.3221, 0.7779,  ..., 0.1592, 0.4372, 0.8763],
#           [0.1491, 0.8995, 0.6539,  ..., 0.8861, 0.4869, 0.4426]],
#
#          [[0.3456, 0.4469, 0.8193,  ..., 0.6649, 0.5941, 0.3415],
#           [0.7699, 0.3077, 0.5993,  ..., 0.2593, 0.6808, 0.4874],
#           [0.0095, 0.4019, 0.0819,  ..., 0.6348, 0.3204, 0.9862],
#           ...,
#           [0.0998, 0.1745, 0.1287,  ..., 0.2838, 0.8699, 0.3030],
#           [0.8586, 0.0425, 0.9034,  ..., 0.7597, 0.8197, 0.8158],
#           [0.7173, 0.2951, 0.9562,  ..., 0.8279, 0.9795, 0.9408]],
#
#          [[0.4522, 0.1666, 0.0525,  ..., 0.0290, 0.0176, 0.1500],
#           [0.5357, 0.1585, 0.8861,  ..., 0.6679, 0.9534, 0.9647],
#           [0.6361, 0.2587, 0.5898,  ..., 0.6474, 0.5940, 0.6533],
#           ...,
#           [0.4226, 0.0890, 0.4814,  ..., 0.2801, 0.7954, 0.3882],
#           [0.7339, 0.6248, 0.9198,  ..., 0.7633, 0.7749, 0.0654],
#           [0.8117, 0.8183, 0.4242,  ..., 0.7828, 0.6485, 0.9251]]],
#
#
#         [[[0.5919, 0.7265, 0.9086,  ..., 0.7013, 0.7167, 0.2324],
#           [0.3972, 0.6721, 0.3580,  ..., 0.4064, 0.4555, 0.9818],
#           [0.6444, 0.5612, 0.7421,  ..., 0.3333, 0.7831, 0.2751],
#           ...,
#           [0.2432, 0.6277, 0.5355,  ..., 0.8173, 0.2055, 0.0276],
#           [0.8298, 0.6457, 0.7450,  ..., 0.7373, 0.7191, 0.8577],
#           [0.3489, 0.4818, 0.0878,  ..., 0.7923, 0.5048, 0.0213]],
#
#          [[0.2986, 0.6775, 0.4591,  ..., 0.7510, 0.8694, 0.0667],
#           [0.4444, 0.7944, 0.5696,  ..., 0.3099, 0.1043, 0.9126],
#           [0.7174, 0.2751, 0.9490,  ..., 0.9531, 0.5244, 0.8832],
#           ...,
#           [0.6199, 0.8085, 0.6804,  ..., 0.1217, 0.6482, 0.5726],
#           [0.8800, 0.7571, 0.8606,  ..., 0.1675, 0.4165, 0.2184],
#           [0.6656, 0.5550, 0.0656,  ..., 0.0161, 0.1795, 0.3280]],
#
#          [[0.6270, 0.1315, 0.9989,  ..., 0.8072, 0.7336, 0.3773],
#           [0.0426, 0.6320, 0.8819,  ..., 0.4362, 0.5982, 0.1057],
#           [0.5788, 0.2992, 0.2428,  ..., 0.8673, 0.6566, 0.5993],
#           ...,
#           [0.5356, 0.2278, 0.5995,  ..., 0.3465, 0.3782, 0.7130],
#           [0.3108, 0.9684, 0.6694,  ..., 0.6949, 0.8585, 0.7172],
#           [0.4430, 0.6577, 0.4531,  ..., 0.1479, 0.6867, 0.7858]],
#
#          [[0.2480, 0.6869, 0.4448,  ..., 0.7800, 0.6513, 0.5439],
#           [0.0852, 0.5584, 0.7694,  ..., 0.8630, 0.2200, 0.7579],
#           [0.8429, 0.4047, 0.7350,  ..., 0.3595, 0.5378, 0.9373],
#           ...,
#           [0.1145, 0.6304, 0.2427,  ..., 0.2635, 0.0622, 0.6569],
#           [0.5415, 0.9210, 0.2646,  ..., 0.0668, 0.6338, 0.1304],
#           [0.7434, 0.3706, 0.6991,  ..., 0.9171, 0.8165, 0.4190]]]])

# %%
torch.norm(a, dim=(2,3))
# Out:
# tensor([[5.9069, 5.8956, 5.8761, 5.6530],
#         [5.6892, 5.8449, 5.6462, 5.2743],
#         [5.9470, 6.0367, 5.6313, 5.8782],
#         [5.4494, 5.9750, 5.8143, 5.5985],
#         [5.8215, 5.7613, 5.6255, 5.8478],
#         [6.0079, 5.9687, 5.7489, 5.8929],
#         [5.4947, 5.7253, 5.7918, 6.3265],
#         [5.7365, 5.7211, 5.3890, 5.6375],
#         [5.4886, 5.7336, 5.8294, 5.5044],
#         [5.8871, 5.3245, 5.9121, 5.4196],
#         [6.0948, 6.0686, 5.3882, 6.1403],
#         [5.7640, 5.4053, 6.2353, 5.8251],
#         [5.3486, 5.5330, 5.7464, 6.0188],
#         [5.3829, 5.7063, 5.6249, 5.3918],
#         [5.7367, 5.9485, 5.9842, 5.6595],
#         [5.7923, 6.2031, 5.9427, 5.7038]])

# %%
loss = torch.pow(torch.norm(a, dim=(2,3)), 2)

# %%
torch.mean(loss,1)
# Out:
# tensor([34.0333, 31.5570, 34.5186, 32.6363, 33.2313, 34.8740, 34.1352, 31.6153,
#         31.8194, 31.8335, 35.1776, 33.8130, 32.1172, 30.5620, 34.0338, 34.9691])

# %%
torch.mean(torch.mean(loss,1))
# Out:
# tensor(33.1829)

# %%
b=torch.tensor([[1.,2.,3.],[4.,5.,6.]])

# %%
torch.norm(b,dim=0)
# Out:
# tensor([4.1231, 5.3852, 6.7082])

# %%
4.1231*4.1231
# Out:
# 16.99995361
