# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file_ssd = '/home/yaoliu/code/UAV/mmdetection/result/compare/ssd512_okutama_c5_weather/ssd512_okutama_c5_weather.py'
checkpoint_file_ssd = '/home/yaoliu/code/UAV/mmdetection/result/compare/ssd512_okutama_c5_weather/epoch_2.pth'

config_file_retina = '/home/yaoliu/code/UAV/mmdetection/result/compare/retinanet_r50_fpn_1x_okutama_c5_ori_weather/retinanet_r50_fpn_1x_okutama_c5_ori_weather.py'
checkpoint_file_retina = '/home/yaoliu/code/UAV/mmdetection/result/compare/retinanet_r50_fpn_1x_okutama_c5_ori_weather/epoch_5.pth'

config_file_v3 = '/home/yaoliu/code/UAV/mmdetection/result/compare/yolox_s_8x8_300e_okutama_class5_weather/yolox_s_8x8_300e_okutama_class5_weather.py'
checkpoint_file_v3 = '/home/yaoliu/code/UAV/mmdetection/result/compare/yolox_s_8x8_300e_okutama_class5_weather/epoch_4.pth'

config_file_x = '/home/yaoliu/code/UAV/mmdetection/result/compare/yolox_s_8x8_300e_okutama_class5_weather/yolox_s_8x8_300e_okutama_class5_weather.py'
checkpoint_file_x = '/home/yaoliu/code/UAV/mmdetection/result/compare/yolox_s_8x8_300e_okutama_class5_weather/epoch_5.pth'

config_file_ours = '/home/yaoliu/code/UAV/mmdetection/result/0901/retinanet_r50_fpn_1x_okutama_c5_att12/retinanet_r50_fpn_1x_okutama_c5_att12.py'
checkpoint_file_ours = '/home/yaoliu/code/UAV/mmdetection/result/0901/retinanet_r50_fpn_1x_okutama_c5_att12/epoch_3.pth'

config_file_ours2 = '/home/yaoliu/code/UAV/mmdetection/result/0901/retinanet_r50_fpn_1x_okutama_c5_att12/retinanet_r50_fpn_1x_okutama_c5_att12.py'
checkpoint_file_ours2 = '/home/yaoliu/code/UAV/mmdetection/result/0901/retinanet_r50_fpn_1x_okutama_c5_att12/epoch_2.pth'

# %%
img_n = './1.png'
img_d = './2.jpg'
img_c = './3.jpg'
img_f = './4.jpg'
img='./2_1_2_170_2.jpg'

# %%
model_ssd = init_detector(config_file_ssd, checkpoint_file_ssd, device='cuda:2')
model_retina = init_detector(config_file_retina, checkpoint_file_retina, device='cuda:2')
# Out:
# load checkpoint from local path: /home/yaoliu/code/UAV/mmdetection/result/compare/ssd512_okutama_c5_weather/epoch_2.pth
# load checkpoint from local path: /home/yaoliu/code/UAV/mmdetection/result/compare/retinanet_r50_fpn_1x_okutama_c5_ori_weather/epoch_5.pth

# %%
model_v3 = init_detector(config_file_v3, checkpoint_file_v3, device='cuda:2')
model_x = init_detector(config_file_x, checkpoint_file_x, device='cuda:2')
# Out:
# load checkpoint from local path: /home/yaoliu/code/UAV/mmdetection/result/compare/yolox_s_8x8_300e_okutama_class5_weather/epoch_4.pth
# The model and loaded state dict do not match exactly
#
# ...

# %%
model_ours = init_detector(config_file_ours, checkpoint_file_ours, device='cuda:2')
model_ours2 = init_detector(config_file_ours2, checkpoint_file_ours2, device='cuda:2')
# Out:
# load checkpoint from local path: /home/yaoliu/code/UAV/mmdetection/result/0901/retinanet_r50_fpn_1x_okutama_c5_att12/epoch_3.pth
# load checkpoint from local path: /home/yaoliu/code/UAV/mmdetection/result/0901/retinanet_r50_fpn_1x_okutama_c5_att12/epoch_2.pth

# %%
result
# Out:
# [array([[1.73227829e+02, 1.82367661e+02, 1.93665863e+02, 2.15121826e+02,
#          1.31524876e-01],
#         [2.62365662e+02, 1.85971619e+02, 2.84549072e+02, 2.22041458e+02,
#          1.02089345e-01]], dtype=float32),
#  array([[1.7376657e+02, 1.8284660e+02, 1.9312990e+02, 2.1537524e+02,
#          2.7802908e-01],
#         [2.6212161e+02, 1.8573549e+02, 2.8450961e+02, 2.2141853e+02,
#          2.0556295e-01],
#         [1.6378049e+02, 1.8343393e+02, 1.8838298e+02, 2.1627185e+02,
#          6.3049942e-02],
#         [1.7876466e+02, 1.7945929e+02, 2.0023904e+02, 2.1459119e+02,
#          6.1456114e-02],
#         [2.5405882e+02, 1.8894374e+02, 2.7943158e+02, 2.2524527e+02,
#          5.9735328e-02]], dtype=float32),
#  array([], shape=(0, 5), dtype=float32),
#  array([[2.6236566e+02, 1.8597162e+02, 2.8454907e+02, 2.2204146e+02,
#          1.0132017e-01],
#         [1.7376657e+02, 1.8284660e+02, 1.9312990e+02, 2.1537524e+02,
#          6.3857660e-02]], dtype=float32),
# ...

# %%
result = inference_detector(model_ours2, img_d)
show_result_pyplot(model_ours2, img_d, result)
